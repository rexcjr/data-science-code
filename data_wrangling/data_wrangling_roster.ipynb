# %%
import pandas as pd
import numpy as np

# %%
# read master roster raw file
fileFolder = r'..\05 OMD\Master Roster'
fileName = 'latest_roster_raw.xlsx'
file = '\\'.join([fileFolder, fileName])
df = pd.read_excel(file, sheet_name = 'Roster')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 87 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Week Start                      1565 non-null   datetime64[ns]
#  1   Site                            1565 non-null   object
#  2   Account                         1565 non-null   object
#  3   Line of Business                1565 non-null   object
#  4   Employee ID                     1564 non-null   float64
#  5   eWFM ID                         1564 non-null   object
#  6   Kronos ID                       1564 non-null   object
#  7   Global ID                       1560 non-null   float64
#  8   VZID                            1559 non-null   object
#  9   Last Name                       1565 non-null   object
#  10  First Name                      1565 non-null   object
#  11  Complete Name                   1565 non-null   object
#  12  Supervisor                      1565 non-null   object
#  13  Manager                         1565 non-null   object
#  14  Trainer                         1467 non-null   object
#  15  Wave                            1565 non-null   object
#  16  Position                        1565 non-null   object
#  17  Role                            1565 non-null   object
#  18  Department                      1565 non-null   object
#  19  Productive/Unproductive         1565 non-null   object
#  20  Work Status                     1565 non-null   object
#  21  Work Status II                  1565 non-null   object
#  22  REASON                          788 non-null    object
#  23  Employee Type                   1565 non-null   object
#  24  Direct/Indirect                 1565 non-null   object
#  25  SYKES Email Address             1565 non-null   object
#  26  Network Login                   1455 non-null   object
#  27  CIMID                           1565 non-null   object
#  28  Phone ID                        1556 non-null   object
#  29  SYKES Hire Date                 1547 non-null   object
#  30  Account Start Date              1564 non-null   datetime64[ns]
#  31  Nesting Date                    1538 non-null   datetime64[ns]
#  32  Live Date                       1536 non-null   object
#  33  Term Date                       1061 non-null   datetime64[ns]
#  34  Tenure in Days                  1564 non-null   float64
#  35  Tenure Category                 1564 non-null   object
#  36  Primary Contact Number          1436 non-null   object
#  37  Home Address                    1446 non-null   object
#  38  Current Address                 1366 non-null   object
#  39  Location / City                 1156 non-null   object
#  40  Compensation                    487 non-null    object
#  41  Previous Account                14 non-null     object
#  42  Tenure with Sykes               1565 non-null   int64
#  43  DOB                             343 non-null    object
#  44  Situational Presence            1565 non-null   object
#  45  With PC?
# Yes / NO              53 non-null     object
#  46  Means of Transportation         812 non-null    object
#  47  Personal Email Address          1152 non-null   object
#  48  Internet Speed                  349 non-null    object
#  49  Staying on Site                 0 non-null      float64
#  50  Permanent Address/City          3 non-null      object
#  51  Gender                          1565 non-null   object
#  52  Community ID                    1565 non-null   object
#  53  CIM Job Title                   1343 non-null   object
#  54  CIM Title                       1342 non-null   object
#  55  CIM Request Date                1221 non-null   object
#  56  Badge #                         0 non-null      float64
#  57  ADA ID                          1565 non-null   object
#  58  SSO ID                          1565 non-null   object
#  59  PERS ID                         1565 non-null   object
#  60  START DATE ID                   1564 non-null   object
#  61  Wave Id                         1565 non-null   object
#  62  ADA Upload                      1564 non-null   object
#  63  Skill Target                    1410 non-null   float64
#  64  Tenure in Days (Nesting Date)   1565 non-null   int64
#  65  Tenure Category (Nesting Date)  1565 non-null   object
#  66  Tenure (Live Date)              1565 non-null   int64
#  67  Tenure Category (Live Date)     1565 non-null   object
#  68  Employee ID.1                   1565 non-null   int64
#  69  External/Internal               1419 non-null   object
#  70  CIM PIN                         625 non-null    object
#  71  Home Internet Service Provider  327 non-null    object
#  72  Corporate/Personal              1137 non-null   object
#  73  Bandwidth                       1136 non-null   object
#  74  Inactive Reason                 0 non-null      float64
#  75  a                               93 non-null     object
#  76  B                               1077 non-null   object
#  77  C                               1077 non-null   float64
#  78  d                               1078 non-null   object
#  79  EMPLOYEE #                      1561 non-null   float64
#  80  WAVE                            1563 non-null   object
#  81  SKILL ID                        1312 non-null   float64
#  82  a.1                             1546 non-null   float64
#  83  VZID vs NT                      0 non-null      float64
#  84  b                               12 non-null     object
#  85  C.1                             0 non-null      float64
#  86  d.1                             0 non-null      float64
# dtypes: datetime64[ns](4), float64(14), int64(4), object(65)
# memory usage: 1.0+ MB

# %%
# select columns
cols = ['CIMID', 'Week Start', 'Site', 'Employee ID', 'Kronos ID', 'Global ID', 'VZID', 'Last Name',
        'First Name', 'Complete Name', 'Supervisor', 'Manager', 'Trainer', 'Wave', 'Position', 'Role', 
        'Department', 'Productive/Unproductive', 'Work Status', 'Work Status II', 'SYKES Hire Date',
        'Account Start Date','Nesting Date', 'Live Date', 'Term Date', 'Tenure Category', 
        'Tenure with Sykes', 'Situational Presence']

df = df[cols]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CIMID                    1565 non-null   object
#  1   Week Start               1565 non-null   datetime64[ns]
#  2   Site                     1565 non-null   object
#  3   Employee ID              1564 non-null   float64
#  4   Kronos ID                1564 non-null   object
#  5   Global ID                1560 non-null   float64
#  6   VZID                     1559 non-null   object
#  7   Last Name                1565 non-null   object
#  8   First Name               1565 non-null   object
#  9   Complete Name            1565 non-null   object
#  10  Supervisor               1565 non-null   object
#  11  Manager                  1565 non-null   object
#  12  Trainer                  1467 non-null   object
#  13  Wave                     1565 non-null   object
#  14  Position                 1565 non-null   object
#  15  Role                     1565 non-null   object
#  16  Department               1565 non-null   object
#  17  Productive/Unproductive  1565 non-null   object
#  18  Work Status              1565 non-null   object
#  19  Work Status II           1565 non-null   object
#  20  SYKES Hire Date          1547 non-null   object
#  21  Account Start Date       1564 non-null   datetime64[ns]
#  22  Nesting Date             1538 non-null   datetime64[ns]
#  23  Live Date                1536 non-null   object
#  24  Term Date                1061 non-null   datetime64[ns]
#  25  Tenure Category          1564 non-null   object
#  26  Tenure with Sykes        1565 non-null   int64
#  27  Situational Presence     1565 non-null   object
# dtypes: datetime64[ns](4), float64(2), int64(1), object(21)
# memory usage: 342.5+ KB

# %%
# Fill NAT of Date cols
df['Live Date'].fillna(df['Account Start Date'] + pd.Timedelta(60), inplace = True )

dt_cols = ['SYKES Hire Date', 'Account Start Date', 'Nesting Date', 'Live Date', 'Term Date']
for col in dt_cols :
    df[col].fillna('1900/1/1', inplace = True )
    print(col + ': ', df[col].isna().sum())
# Out:
# SYKES Hire Date:  0
# Account Start Date:  0
# Nesting Date:  0
# Live Date:  0
# Term Date:  0

# %%
df.loc[df['Employee ID'] == 10609395, 'Live Date'] = '1900-1-1'
ren = df.loc[df['Employee ID'] == 10609395]

# %%
# clean data types
df['CIMID'] = pd.to_numeric(df['CIMID'], errors = 'coerce').fillna(0).astype('float64')
df['Employee ID'] = pd.to_numeric(df['Employee ID'], errors = 'coerce').fillna(0).astype('float64')
df['Global ID'] = pd.to_numeric(df['Global ID'], errors = 'coerce').fillna(0)
df['Wave'] = pd.to_numeric(df['Wave'], errors = 'coerce')


for col in dt_cols :
    df[col] = pd.to_datetime(df[col]).dt.normalize()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CIMID                    1565 non-null   float64
#  1   Week Start               1565 non-null   datetime64[ns]
#  2   Site                     1565 non-null   object
#  3   Employee ID              1565 non-null   float64
#  4   Kronos ID                1564 non-null   object
#  5   Global ID                1565 non-null   float64
#  6   VZID                     1559 non-null   object
#  7   Last Name                1565 non-null   object
#  8   First Name               1565 non-null   object
#  9   Complete Name            1565 non-null   object
#  10  Supervisor               1565 non-null   object
#  11  Manager                  1565 non-null   object
#  12  Trainer                  1467 non-null   object
#  13  Wave                     1563 non-null   float64
#  14  Position                 1565 non-null   object
#  15  Role                     1565 non-null   object
#  16  Department               1565 non-null   object
#  17  Productive/Unproductive  1565 non-null   object
#  18  Work Status              1565 non-null   object
#  19  Work Status II           1565 non-null   object
#  20  SYKES Hire Date          1565 non-null   datetime64[ns]
#  21  Account Start Date       1565 non-null   datetime64[ns]
#  22  Nesting Date             1565 non-null   datetime64[ns]
#  23  Live Date                1565 non-null   datetime64[ns]
#  24  Term Date                1565 non-null   datetime64[ns]
#  25  Tenure Category          1564 non-null   object
#  26  Tenure with Sykes        1565 non-null   int64
#  27  Situational Presence     1565 non-null   object
# dtypes: datetime64[ns](6), float64(4), int64(1), object(17)
# memory usage: 342.5+ KB

# %%
df[df['Live Date'].isna()]
# Out:
# Empty DataFrame
# Columns: [CIMID, Week Start, Site, Employee ID, Kronos ID, Global ID, VZID, Last Name, First Name, Complete Name, Supervisor, Manager, Trainer, Wave, Position, Role, Department, Productive/Unproductive, Work Status, Work Status II, SYKES Hire Date, Account Start Date, Nesting Date, Live Date, Term Date, Tenure Category, Tenure with Sykes, Situational Presence]
# Index: []
#
# [0 rows x 28 columns]

# %%
# check dups
df = df.drop_duplicates(['Global ID'], keep ='last')
df.duplicated(['Global ID']).sum()
# Out:
# 0

# %%
# clean Wave column
pd.set_option("display.max_rows", None, "display.max_columns", None)

df['Wave'] = df['Wave'].apply(np.floor)
df['Wave'] = df['Wave'].fillna(-99)
df['Wave'] = df['Wave'].astype('float64')
df['Wave'].value_counts(ascending = True)
# Out:
# -99.0     2
#  34.0     6
#  4.0      7
#  1.0      9
#  8.0      9
#  19.0    10
#  23.0    11
#  12.0    12
#  2.0     12
#  9.0     12
#  7.0     13
#  18.0    14
#  24.0    14
#  6.0     14
#  5.0     14
#  3.0     14
#  15.0    15
#  11.0    15
#  17.0    16
#  10.0    17
#  16.0    17
#  22.0    17
#  20.0    18
#  25.0    18
#  13.0    18
#  26.0    19
#  40.0    19
#  30.0    19
#  32.0    20
#  27.0    20
#  33.0    21
#  14.0    21
#  41.0    23
#  60.0    23
#  35.0    23
#  43.0    23
#  21.0    23
#  51.0    24
#  45.0    24
#  28.0    24
#  29.0    24
#  37.0    24
#  36.0    24
#  52.0    24
#  61.0    25
#  42.0    25
#  44.0    25
#  46.0    25
#  48.0    25
#  49.0    25
#  63.0    25
#  31.0    25
#  39.0    26
#  53.0    26
#  0.0     27
#  47.0    27
#  38.0    27
#  50.0    33
#  59.0    35
#  58.0    40
#  62.0    45
#  64.0    51
#  55.0    64
#  57.0    64
#  54.0    70
#  56.0    79
# Name: Wave, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1560 entries, 0 to 1564
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CIMID                    1560 non-null   float64
#  1   Week Start               1560 non-null   datetime64[ns]
#  2   Site                     1560 non-null   object
#  3   Employee ID              1560 non-null   float64
#  4   Kronos ID                1560 non-null   object
#  5   Global ID                1560 non-null   float64
#  6   VZID                     1558 non-null   object
#  7   Last Name                1560 non-null   object
#  8   First Name               1560 non-null   object
#  9   Complete Name            1560 non-null   object
#  10  Supervisor               1560 non-null   object
#  11  Manager                  1560 non-null   object
#  12  Trainer                  1462 non-null   object
#  13  Wave                     1560 non-null   float64
#  14  Position                 1560 non-null   object
#  15  Role                     1560 non-null   object
#  16  Department               1560 non-null   object
#  17  Productive/Unproductive  1560 non-null   object
#  18  Work Status              1560 non-null   object
#  19  Work Status II           1560 non-null   object
#  20  SYKES Hire Date          1560 non-null   datetime64[ns]
#  21  Account Start Date       1560 non-null   datetime64[ns]
#  22  Nesting Date             1560 non-null   datetime64[ns]
#  23  Live Date                1560 non-null   datetime64[ns]
#  24  Term Date                1560 non-null   datetime64[ns]
#  25  Tenure Category          1559 non-null   object
#  26  Tenure with Sykes        1560 non-null   int64
#  27  Situational Presence     1560 non-null   object
# dtypes: datetime64[ns](6), float64(4), int64(1), object(17)
# memory usage: 353.4+ KB

# %%
df.to_excel(r'..\Master Roster\clean_roster_frm_python.xlsx',
           index = False)

# %%
# MS Access SQL query
# read Roster table from MS Access BGCO DB
import pyodbc

db = r'..\Documents\BGCO DB.accdb;'
driver = r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};'
conn = pyodbc.connect(driver + 'DBQ={}'.format(db) )
cursor = conn.cursor()

select_all_query = '''
    SELECT * 
    FROM Roster
'''

df_db = pd.read_sql(select_all_query, conn)
cursor.commit()

# %%
# del Roster data
del_all_rows_query = '''
    DELETE 
    FROM Roster
'''

cursor.execute(del_all_rows_query)
df_db = pd.read_sql(select_all_query, conn)
cursor.commit()

# %%
df.columns
# Out:
# Index(['CIMID', 'Week Start', 'Site', 'Employee ID', 'Kronos ID', 'Global ID',
#        'VZID', 'Last Name', 'First Name', 'Complete Name', 'Supervisor',
#        'Manager', 'Trainer', 'Wave', 'Position', 'Role', 'Department',
#        'Productive/Unproductive', 'Work Status', 'Work Status II',
#        'SYKES Hire Date', 'Account Start Date', 'Nesting Date', 'Live Date',
#        'Term Date', 'Tenure Category', 'Tenure with Sykes',
#        'Situational Presence'],
#       dtype='object')

# %%
# insert clean df to Roster table
insert_df = '''
    INSERT INTO 
        Roster(
            CIMID, [Week Start], [Site], [Employee ID], [Kronos ID], [Global ID], [VZID], [Last Name], 
            [First Name], [Complete Name], [Supervisor], [Manager], [Trainer], [Wave], [Position], [Role], 
            [Department], [Productive/Unproductive], [Work Status], [Work Status II], [SYKES Hire Date], 
            [Account Start Date], [Nesting Date], [Live Date], [Term Date], [Tenure Category], 
            [Tenure with Sykes], [Situational Presence]
        ) 
        VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
'''
for idx, row in df.iterrows():
    cursor.execute(insert_df, row['CIMID'], row['Week Start'], row['Site'], row['Employee ID'], row['Kronos ID'], 
                   row['Global ID'], row['VZID'], row['Last Name'], row['First Name'], row['Complete Name'], 
                   row['Supervisor'], row['Manager'], row['Trainer'], row['Wave'], row['Position'], row['Role'], 
                   row['Department'], row['Productive/Unproductive'], row['Work Status'], row['Work Status II'], 
                   row['SYKES Hire Date'], row['Account Start Date'], row['Nesting Date'], row['Live Date'], 
                   row['Term Date'], row['Tenure Category'],row['Tenure with Sykes'],row['Situational Presence']
                  ) 

cursor.commit()

# %%
# read updated Roster table
df_db = pd.read_sql(select_all_query, conn)
conn.close()

df_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CIMID                    1560 non-null   float64
#  1   Week Start               1560 non-null   datetime64[ns]
#  2   Site                     1560 non-null   object
#  3   Account                  0 non-null      object
#  4   Line of Business         0 non-null      object
#  5   Employee ID              1560 non-null   float64
#  6   eWFM ID                  0 non-null      object
#  7   Kronos ID                1560 non-null   object
#  8   Global ID                1560 non-null   float64
#  9   VZID                     1560 non-null   object
#  10  Last Name                1560 non-null   object
#  11  First Name               1560 non-null   object
#  12  Complete Name            1560 non-null   object
#  13  Supervisor               1560 non-null   object
#  14  Manager                  1560 non-null   object
#  15  Trainer                  1560 non-null   object
#  16  Wave                     1560 non-null   float64
#  17  Position                 1560 non-null   object
#  18  Role                     1560 non-null   object
#  19  Department               1560 non-null   object
#  20  Productive/Unproductive  1560 non-null   object
#  21  Work Status              1560 non-null   object
#  22  Work Status II           1560 non-null   object
#  23  CIMID2                   0 non-null      object
#  24  Phone ID                 0 non-null      object
#  25  SYKES Hire Date          1560 non-null   object
#  26  Account Start Date       1560 non-null   object
#  27  Nesting Date             1560 non-null   datetime64[ns]
#  28  Live Date                1560 non-null   datetime64[ns]
#  29  Term Date                1560 non-null   datetime64[ns]
#  30  Tenure in Days           1560 non-null   int64
#  31  Tenure Category          1560 non-null   object
#  32  Primary Contact Number   0 non-null      object
#  33  Home Address             0 non-null      object
#  34  Current Address          0 non-null      object
#  35  Location / City          0 non-null      object
#  36  Compensation             0 non-null      object
#  37  Previous Account         0 non-null      object
#  38  Tenure with Sykes        1560 non-null   float64
#  39  DOB                      0 non-null      object
#  40  Situational Presence     1560 non-null   object
# dtypes: datetime64[ns](4), float64(5), int64(1), object(31)
# memory usage: 499.8+ KB

# %%
# MS Access SQL query for main query

db = r'..\Documents\BGCO DB.accdb;'
driver = r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};'
conn = pyodbc.connect(driver + 'DBQ={}'.format(db) )
main_query = ''' 
    SELECT *
    FROM 0_bgco_main_query
    WHERE month_year = '2022-02' or month_year = '2022-03'
    ORDER BY stat_date ;
'''
                     
df_main_query = pd.read_sql(main_query, conn)

conn.close()                     

df_main_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14374 entries, 0 to 14373
# Data columns (total 50 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CIM_Worker_ID                 14374 non-null  float64
#  1   rpt_mth                       14374 non-null  datetime64[ns]
#  2   month_year                    14374 non-null  object
#  3   stat_date                     14374 non-null  datetime64[ns]
#  4   EMPLOYEE_NAME                 14374 non-null  object
#  5   RepHandledCalls               14374 non-null  float64
#  6   TransferCalls                 14374 non-null  float64
#  7   nps_promoter                  14374 non-null  float64
#  8   nps_detractor                 14374 non-null  float64
#  9   nps_surveys                   14374 non-null  float64
#  10  TechTransfers                 14374 non-null  float64
#  11  Net_OCC                       14374 non-null  float64
#  12  disconnects                   14374 non-null  int64
#  13  RepeatCalls2hr                14374 non-null  int64
#  14  TotalCallsFor2hrRepeats       14374 non-null  float64
#  15  Accessory_Amt                 14374 non-null  float64
#  16  Total_Upgrades                14374 non-null  float64
#  17  Available_Time                14374 non-null  float64
#  18  Signed_On_Time                14374 non-null  float64
#  19  Talk_Time                     14374 non-null  float64
#  20  Hold_Time                     14374 non-null  float64
#  21  Work_Time                     14374 non-null  float64
#  22  VIRTUAL_LOCATION_DESCRIPTION  14374 non-null  object
#  23  Phone_Overall_Int_Completed   14374 non-null  float64
#  24  Phone_Overall_Int_Surveys     14374 non-null  float64
#  25  acd_calls_handled             14374 non-null  int64
#  26  Situational Presence          14374 non-null  object
#  27  SYKES Hire Date               14374 non-null  object
#  28  Wave                          14374 non-null  float64
#  29  Supervisor                    14374 non-null  object
#  30  Manager                       14374 non-null  object
#  31  Role                          14374 non-null  object
#  32  Employee ID                   14374 non-null  float64
#  33  Trainer                       14374 non-null  object
#  34  Work Status                   14374 non-null  object
#  35  Work Status II                14374 non-null  object
#  36  Nesting Date                  14374 non-null  datetime64[ns]
#  37  Tenure Category               14374 non-null  object
#  38  Workweek                      14374 non-null  datetime64[ns]
#  39  Day_of_Week                   14374 non-null  object
#  40  DoM                           14374 non-null  int64
#  41  Tenure Days                   14374 non-null  float64
#  42  NestingDay                    14374 non-null  float64
#  43  Nesting Week                  14374 non-null  object
#  44  Tenure Group                  14374 non-null  object
#  45  Tenure Group2                 14374 non-null  object
#  46  Tenure Group3                 14374 non-null  object
#  47  Tenure Week                   14374 non-null  object
#  48  Tenure Week >WK12             14374 non-null  object
#  49  TenureFrNesting               14374 non-null  object
# dtypes: datetime64[ns](4), float64(22), int64(4), object(20)
# memory usage: 5.5+ MB
