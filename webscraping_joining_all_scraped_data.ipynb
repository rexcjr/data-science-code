# %% [markdown]
# # Prepare Tourist Data per Location
#
# <b>Disclaimers: </b>
#
# - All of the data extracted are not my own and are properties of www.booking.com, www.zomato.com, and www.tripadvisor.com.ph and data will not be used for commercial purposes
# - Scraped data are not used for commercial purposes and purely for personal education purposes

# %%
# import needed libraries
import pandas as pd

# %%
# read all needed csv files
hotel = pd.read_csv('Hotel.csv')
resto = pd.read_csv('Restaurant.csv')
tourist = pd.read_csv('Tourist_site.csv')

#view info
hotel.info()
resto.info()
tourist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   hotel_name                 25 non-null     object
#  1   hotel_location             25 non-null     object
#  2   hotel_amenities            25 non-null     object
#  3   hotel_min_price_range_php  25 non-null     object
#  4   hotel_avail_rooms          25 non-null     object
#  5   hotel_other_info           25 non-null     object
#  6   hotel_reviews              25 non-null     object
# dtypes: object(7)
# memory usage: 1.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   restaurant_name         27 non-null     object
#  1   restaurant_location     27 non-null     object
#  2   resto_specialty         27 non-null     object
#  3   restaurant_price_range  27 non-null     object
#  4   seat_capacity           27 non-null     object
#  5   restaurant_other_info   27 non-null     object
#  6   restaurant_reviews      27 non-null     object
# dtypes: object(7)
# memory usage: 1.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   tourist_site_name                       30 non-null     object
#  1   tourist_site_classification             30 non-null     object
#  2   tourist_site_location                   30 non-null     object
#  3   tourist_site_other_info_overall_rating  30 non-null     object
#  4   tourist_site_reviews                    30 non-null     object
#  5   approx_visitors_per_year_in_thousands   30 non-null     int64
#  6   tourist_site_entance_fee_in_pesos       30 non-null     int64
# dtypes: int64(2), object(5)
# memory usage: 1.8+ KB

# %%
# standardize location column names
hotel.rename(columns = {'hotel_location' : 'location'}, inplace = True)
resto.rename(columns = {'restaurant_location' : 'location'}, inplace = True)
tourist.rename(columns = {'tourist_site_location' : 'location'}, inplace = True)

# create new column category for indexing later
hotel['category'] = 'hotels'
resto['category'] = 'restaurants'
tourist['category'] = 'tourist_sites'

# remove whitespaces
dfs = [hotel, resto, tourist]
for df in dfs :
    df['location'] = df['location'].apply(lambda x: x.strip())
    print('=====')
    print(df[['location', 'category']].head(3))
    
# clean location names
hotel.loc[hotel['location'] == 'Paranaque City'] = 'Parañaque City'
# Out:
# =====
#           location category
# 0       Pasay City   hotels
# 1  Muntinlupa City   hotels
# 2       Pasig City   hotels
# =====
#          location     category
# 0     Quezon City  restaurants
# 1     Makati City  restaurants
# 2  Parañaque City  restaurants
# =====
#       location       category
# 0  Manila City  tourist_sites
# 1  Quezon City  tourist_sites
# 2  Manila City  tourist_sites

# %%
# view location per dataframes and count total
print('=======Hotels=======')
print(hotel.location.value_counts())
print('Total:', hotel.location.value_counts().sum())
print('=======Restaurants=======')
print(resto.location.value_counts())
print('Total:', resto.location.value_counts().sum())
print('=======Tourist Sites=======')
print(tourist.location.value_counts())
print('Total:', tourist.location.value_counts().sum())
# Out:
# =======Hotels=======
# Pasay City         7
# Makati City        6
# Quezon City        5
# Pasig City         3
# Muntinlupa City    2
# Parañaque City     1
# Manila City        1
# Name: location, dtype: int64
# Total: 25
# =======Restaurants=======
# Quezon City        10
# Taguig City         6
# Makati City         3
# Muntinlupa City     2
# Parañaque City      1
# Las Piñas City      1
# Tagaytay City       1
# Pasig City          1
# San Juan City       1
# Pasay City          1
# Name: location, dtype: int64
# Total: 27
# =======Tourist Sites=======
# Manila City         12
# Pasay City           6
# Quezon City          3
# Taguig City          3
# Makati City          3
# Mandaluyong City     1
# San Juan City        1
# Muntinlupa City      1
# Name: location, dtype: int64
# Total: 30

# %%
# index location and category and merge the 3 dataframes
index = ['location', 'category']
merged_df = hotel.merge(resto, how = 'outer', on = index).set_index(index)
overall_df = merged_df.merge(tourist, how = 'outer', on = index).set_index(index)
overall_df.drop_duplicates()
overall_df.head(10)
# Out:
#                                                    hotel_name  \
# location        category
# Pasay City      hotels        Sofitel Philippine Plaza Manila
#                 hotels                          Conrad Manila
#                 hotels                Selah Pods Hotel Manila
#                 hotels                                Asiatel
#                 hotels                          Hilton Manila
#                 hotels    Tryp By Wyndham Mall Of Asia Manila
#                 hotels                 Midas Hotel And Casino
# Muntinlupa City hotels                         Azumi Boutique
#                 hotels          Crimson Filinvest City Manila
# Pasig City      hotels              Marco Polo Ortigas Manila
#
#                                                             hotel_amenities  \
# location        category
# Pasay City      hotels    1 swimming pool, Airport shuttle, Non-smoking ...
#                 hotels    1 swimming pool, Airport shuttle, Non-smoking ...
#                 hotels    Non-smoking rooms, Family rooms, Free WiFi, Ro...
#                 hotels    Non-smoking rooms, Free WiFi, Restaurant, Room...
#                 hotels    1 swimming pool, Airport shuttle, Non-smoking ...
#                 hotels    1 swimming pool, Airport shuttle, Non-smoking ...
#                 hotels    Airport shuttle, Non-smoking rooms, Family roo...
# Muntinlupa City hotels    1 swimming pool, Airport shuttle, Non-smoking ...
#                 hotels    1 swimming pool, Airport shuttle, Non-smoking ...
# Pasig City      hotels    1 swimming pool, Airport shuttle, Non-smoking ...
#
#                          hotel_min_price_range_php  \
# location        category
# Pasay City      hotels                  10k and up
#                 hotels                  10k and up
#                 hotels                   5k to 10k
#                 hotels                   5k to 10k
#                 hotels                   5k to 10k
#                 hotels                   5k to 10k
#                 hotels                   5k to 10k
# Muntinlupa City hotels                   5k to 10k
#                 hotels                  10k and up
# Pasig City      hotels                  10k and up
#
#                                                           hotel_avail_rooms  \
# location        category
# Pasay City      hotels    {'Luxury King Room with Bay View': 'Only 7 roo...
#                 hotels    {'Deluxe King Room with Panorama Bay View': 'O...
#                 hotels    {'Standard Double Room without View': 'Only 2 ...
#                 hotels          {'Suite Family': 'Only 6 left on our site'}
#                 hotels    {'King Room': 'Only 6 rooms left on our site',...
#                 hotels    {'Twin Room with Bay View': 'More than 7 avail...
#                 hotels    {'Executive Double or Twin Room': 'More than 7...
# Muntinlupa City hotels    {'King Room': 'Only 5 rooms left on our site',...
#                 hotels    {'One Bedroom Suite Double Room': 'Only 3 left...
# Pasig City      hotels    {'Continental Superior King Room': 'Only 4 roo...
#
#                                                            hotel_other_info  \
# location        category
# Pasay City      hotels    Located in Pasay City, Sofitel Philippine Plaz...
#                 hotels    Featuring free WiFi in public areas, Conrad Ma...
#                 hotels    You're eligible for a Genius discount at Selah...
#                 hotels    You're eligible for a Genius discount at OYO 1...
#                 hotels    Set within Resorts World Manila, 2-minute walk...
#                 hotels    Overlooking the Manila Bay, TRYP by Wyndham Ma...
#                 hotels    Situated along Roxas Boulevard offering views ...
# Muntinlupa City hotels    You're eligible for a Genius discount at Azumi...
#                 hotels    You're eligible for a Genius discount at Crims...
# Pasig City      hotels    Located in the heart of Manila’s city centre, ...
#
#                                                               hotel_reviews  \
# location        category
# Pasay City      hotels    Reviewer Name: \nStefan\n\nReview: There was n...
#                 hotels    Reviewer Name: \nJoe\n\nReview: excellent cust...
#                 hotels    Reviewer Name: \nMaribel\n\nReview: bathroom  ...
#                 hotels    Reviewer Name: \nJohn\n\nReview: Information f...
#                 hotels    Reviewer Name: \nShaina\n\nReview: Pool was so...
#                 hotels    Reviewer Name: \nYoyoshin\n\nReview: the place...
#                 hotels    Reviewer Name: \nGerald\n\nReview: Upgrade to ...
# Muntinlupa City hotels    Reviewer Name: \nMaria\n\nReview: None  Servic...
#                 hotels    Reviewer Name: \nCaroline\n\nReview: the beddi...
# Pasig City      hotels    Reviewer Name: \nJanet\n\nReview: No buffet ye...
#
#                          restaurant_name resto_specialty  \
# location        category
# Pasay City      hotels               NaN             NaN
#                 hotels               NaN             NaN
#                 hotels               NaN             NaN
#                 hotels               NaN             NaN
#                 hotels               NaN             NaN
#                 hotels               NaN             NaN
#                 hotels               NaN             NaN
# Muntinlupa City hotels               NaN             NaN
#                 hotels               NaN             NaN
# Pasig City      hotels               NaN             NaN
#
#                          restaurant_price_range seat_capacity  \
# location        category
# Pasay City      hotels                      NaN           NaN
#                 hotels                      NaN           NaN
#                 hotels                      NaN           NaN
#                 hotels                      NaN           NaN
#                 hotels                      NaN           NaN
#                 hotels                      NaN           NaN
#                 hotels                      NaN           NaN
# Muntinlupa City hotels                      NaN           NaN
#                 hotels                      NaN           NaN
# Pasig City      hotels                      NaN           NaN
#
#                          restaurant_other_info restaurant_reviews  \
# location        category
# Pasay City      hotels                     NaN                NaN
#                 hotels                     NaN                NaN
#                 hotels                     NaN                NaN
#                 hotels                     NaN                NaN
#                 hotels                     NaN                NaN
#                 hotels                     NaN                NaN
#                 hotels                     NaN                NaN
# Muntinlupa City hotels                     NaN                NaN
#                 hotels                     NaN                NaN
# Pasig City      hotels                     NaN                NaN
#
#                          tourist_site_name tourist_site_classification  \
# location        category
# Pasay City      hotels                 NaN                         NaN
#                 hotels                 NaN                         NaN
#                 hotels                 NaN                         NaN
#                 hotels                 NaN                         NaN
#                 hotels                 NaN                         NaN
#                 hotels                 NaN                         NaN
#                 hotels                 NaN                         NaN
# Muntinlupa City hotels                 NaN                         NaN
#                 hotels                 NaN                         NaN
# Pasig City      hotels                 NaN                         NaN
#
#                          tourist_site_other_info_overall_rating  \
# location        category
# Pasay City      hotels                                      NaN
#                 hotels                                      NaN
#                 hotels                                      NaN
#                 hotels                                      NaN
#                 hotels                                      NaN
#                 hotels                                      NaN
#                 hotels                                      NaN
# Muntinlupa City hotels                                      NaN
#                 hotels                                      NaN
# Pasig City      hotels                                      NaN
#
#                          tourist_site_reviews  \
# location        category
# Pasay City      hotels                    NaN
#                 hotels                    NaN
#                 hotels                    NaN
#                 hotels                    NaN
#                 hotels                    NaN
#                 hotels                    NaN
#                 hotels                    NaN
# Muntinlupa City hotels                    NaN
#                 hotels                    NaN
# Pasig City      hotels                    NaN
#
#                           approx_visitors_per_year_in_thousands  \
# location        category
# Pasay City      hotels                                      NaN
#                 hotels                                      NaN
#                 hotels                                      NaN
#                 hotels                                      NaN
#                 hotels                                      NaN
#                 hotels                                      NaN
#                 hotels                                      NaN
# Muntinlupa City hotels                                      NaN
#                 hotels                                      NaN
# Pasig City      hotels                                      NaN
#
#                           tourist_site_entance_fee_in_pesos
# location        category
# Pasay City      hotels                                  NaN
#                 hotels                                  NaN
#                 hotels                                  NaN
#                 hotels                                  NaN
#                 hotels                                  NaN
#                 hotels                                  NaN
#                 hotels                                  NaN
# Muntinlupa City hotels                                  NaN
#                 hotels                                  NaN
# Pasig City      hotels                                  NaN

# %%
# count location and breakdown per category
count_loc = overall_df.groupby(level='location').size().sort_values(ascending = False)

# I chose Quezon City location since it has the most data
qc = overall_df.filter(like = 'Quezon City', axis = 0)

print(count_loc)
print('Total:', count_loc.sum())
print('Check Count of Quezon City:', len(qc))
# Out:
# location
# Quezon City         18
# Pasay City          14
# Manila City         13
# Makati City         12
# Taguig City          9
# Muntinlupa City      5
# Pasig City           4
# Parañaque City       2
# San Juan City        2
# Las Piñas City       1
# Mandaluyong City     1
# Tagaytay City        1
# dtype: int64
# Total: 82
# Check Count of Quezon City: 18

# %%
# save to csv
qc.to_csv('Location.csv')
