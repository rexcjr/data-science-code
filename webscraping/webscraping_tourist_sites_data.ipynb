# %% [markdown]
# # Prepare Tourist Site data

# %%
# import needed libraries
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# # Web scraping www.tripadvisor.com.ph to extract tourist sites data.
# <b>Disclaimers: </b>
#
# - All of the data extracted are not my own and are properties of www.tripadvisor.com.ph
# - Scraped data are not used for commercial purposes and purely for personal education purposes
# - HTML, format, tags, parameters, and other website script used as reference are working as of this writing and may change anytime by the website owner/administrators which may impact this code
# - The code blocks may take 0-2mins depending on hardware/software/network capabilities. If you want to rerun, patience is appreciated
# - Imported time module to avoid overloading the site and get blocked

# %% [markdown]
# ## Use Search Url and create BeautifulSoup object

# %%
# set headers for scraping
headers = {
        'Access-Control-Allow-Origin': '*',
        'Access-Control-Allow-Methods': 'GET',
        'Access-Control-Allow-Headers': 'Content-Type',
        'Access-Control-Max-Age': '3600',
        "User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36"
    }

# get html text and create BeautifulSoup object 
search_url = 'https://www.tripadvisor.com.ph/Attractions-g298449-Activities-a_allAttractions.true-zft11309-Metro_Manila_Luzon.html'
search_html = requests.get(search_url, headers = headers)    
search_soup = BeautifulSoup(search_html.text, 'html.parser')

# %%
# extract tourist site links based from the search result page

# Use 3 lines below this to find the link_class 
#a_tags = search_soup.find_all('a') 
#for tag in a_tags :
    #print(tag)

links_class = {'class' : 'FmrIP _R w _Z P0 M0 Gm ddFHE'}
a_tags = search_soup.find_all('a', links_class) # find a tags
main_url = 'https://www.tripadvisor.com.ph'

# iterate and append all links in a list
tour_links_lst = []
for tag in a_tags :
    tour_links_lst.append(main_url + tag.get('href') ) 
     
print('Scraping Complete!')
print('Count of Tourist Site Links : ', len(tour_links_lst) )
print('Sample Links:')
for link in tour_links_lst[0:3] : print(link)
# Out:
# Scraping Complete!
# Count of Tourist Site Links :  30
# Sample Links:
# https://www.tripadvisor.com.ph/Attraction_Review-g298573-d310887-Reviews-National_Museum-Manila_Metro_Manila_Luzon.html
# https://www.tripadvisor.com.ph/Attraction_Review-g298574-d7396573-Reviews-Art_in_Island-Quezon_City_Metro_Manila_Luzon.html
# https://www.tripadvisor.com.ph/Attraction_Review-g298573-d586732-Reviews-Fort_Santiago-Manila_Metro_Manila_Luzon.html

# %%
# iterate over each tourist site link to scrape the data of each 
tour_main_dict = {}
for tour_link in tour_links_lst :
    tour_details_dict = {}
    tour_html = requests.get(tour_link, headers = headers)    
    tour_soup = BeautifulSoup(tour_html.text, 'lxml')
    
    # Extract attraction name and add to details dictionary
    name = tour_soup.find('h1', {'class' : 'WlYyy cPsXC GeSzT'} ).get_text()
    tour_details_dict['tourist_site_name'] = name
    
    # Extract tourist site classification and add to details dictionary
    type_tag = tour_soup.find_all('div', {'class' : 'WlYyy diXIH dDKKM'})
    for tag in type_tag[4:5] :
        tour_classification = tag.get_text()
    tour_details_dict['tourist_site_classification'] = tour_classification
    
    # Extract tourist site location and add to details dictionary
    loc_tag = tour_soup.find('div', {'class' : 'dIDBU MJ'} )
    if loc_tag != None :
        tour_loc = loc_tag.get_text().split('Address')[-1]
    else : 
        tour_loc = tour_link.split('-')[-1].replace('_', ' ').split('.html')[0] 
    
    tour_details_dict['tourist_site_location'] = tour_loc

    # Extract tourist site other info (overall rating) and add to details dictionary
    other_tag = tour_soup.find_all('div', {'class' : 'WlYyy cPsXC fksET cMKSg'} )
    for tag in other_tag :
        other_info = tag.get_text() + '/5.0'
    tour_details_dict['tourist_site_other_info_overall_rating'] = other_info
    
    # Extract reviews and add to details dictionary
    reviews_tag = tour_soup.find_all('div', {'class' : 'pIRBV _T KRIav'})
    rev_count = 0
    tour_review = ''
    for tag in reviews_tag[1:4] :
        if tag.get_text() == '' : continue
        rev_count += 1
        tour_review = tour_review = tour_review + '\n' + 'Review #' + str(rev_count) + '\n' + tag.get_text()
    tour_details_dict['tourist_site_reviews'] = tour_review.lstrip()
    tour_main_dict[name] = tour_details_dict # add all scraped details of each tourist site
    time.sleep(1)
    
print('Scraping Complete!')
print('Count of Hotels:', len(tour_main_dict))
# Out:
# Scraping Complete!
# Count of Hotels: 30

# %%
# Create Dataframe from tour_main_dict
df = pd.DataFrame.from_dict(tour_main_dict, orient = 'index')
df.info()
df.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, National Museum to Philippine Air Force Aerospace Museum
# Data columns (total 5 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   tourist_site_name                       30 non-null     object
#  1   tourist_site_classification             30 non-null     object
#  2   tourist_site_location                   30 non-null     object
#  3   tourist_site_other_info_overall_rating  30 non-null     object
#  4   tourist_site_reviews                    30 non-null     object
# dtypes: object(5)
# memory usage: 1.4+ KB
#                 tourist_site_name tourist_site_classification  \
# National Museum   National Museum          Speciality Museums
#
#                                              tourist_site_location  \
# National Museum  Padre Burgos Ave Ermita, Manila, Luzon 2004 Ph...
#
#                 tourist_site_other_info_overall_rating  \
# National Museum                                4.0/5.0
#
#                                               tourist_site_reviews
# National Museum  Review #1\nWe really loved the paintings at th...

# %%
# lean location data
def clean_loc(s) :
    if ',' not in s :
        r = s.split(' ')[0]
    else : 
        r = s.split(',')[-2]
    return r.strip() + ' City'
     
df['tourist_site_location'] = df['tourist_site_location'].apply(clean_loc)
df.tourist_site_location.loc[df['tourist_site_location'] == 'Quezon City City'] = 'Quezon City'
df.tourist_site_location.loc[df['tourist_site_location'] == 'San City'] = 'San Juan City'
df.tourist_site_location.loc[df['tourist_site_location'] == 'Taguig City City'] = 'Taguig City'
#for loc in df.tourist_site_location.values :
    #print(loc)

df.tourist_site_location.value_counts()
# Out:
# Manila City         12
# Pasay City           6
# Quezon City          3
# Taguig City          3
# Makati City          3
# Mandaluyong City     1
# San Juan City        1
# Muntinlupa City      1
# Name: tourist_site_location, dtype: int64

# %%
# Number of Visitors per year and entrance fee are based on research that are available
# PSA, or other review site doesn't usually provide these data
# See tourist_site_visitors_and_price.csv for references

import_df = pd.read_csv('tourist_site_visitors_and_price.csv', index_col = 'tourist_site_name')
import_df.head(3)
# Out:
#                    approx_visitors_per_year_in_thousands  \
# tourist_site_name
# National Museum                                      730
# Art in Island                                         50
# Fort Santiago                                      37000
#
#                    tourist_site_entance_fee_in_pesos  \
# tourist_site_name
# National Museum                                    0
# Art in Island                                    500
# Fort Santiago                                      0
#
#                                                           references
# tourist_site_name
# National Museum    https://www.philstar.com/business/2018/06/06/1...
# Art in Island                        Art In Island - Home | Facebook
# Fort Santiago                https://www.pna.gov.ph/articles/1095487

# %%
import_df = import_df.drop(['references'], axis = 1)
import_df.head(3)
# Out:
#                    approx_visitors_per_year_in_thousands  \
# tourist_site_name
# National Museum                                      730
# Art in Island                                         50
# Fort Santiago                                      37000
#
#                    tourist_site_entance_fee_in_pesos
# tourist_site_name
# National Museum                                    0
# Art in Island                                    500
# Fort Santiago                                      0

# %%
# join 2 df, save to csv
df.set_index('tourist_site_name', inplace = True)
final_df = df.merge(import_df, how = 'left', on = 'tourist_site_name' )
final_df.info()
final_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, National Museum to Philippine Air Force Aerospace Museum
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   tourist_site_classification             30 non-null     object
#  1   tourist_site_location                   30 non-null     object
#  2   tourist_site_other_info_overall_rating  30 non-null     object
#  3   tourist_site_reviews                    30 non-null     object
#  4   approx_visitors_per_year_in_thousands   30 non-null     int64
#  5   tourist_site_entance_fee_in_pesos       30 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 1.6+ KB
#                                                                 tourist_site_classification  \
# tourist_site_name
# National Museum                                                          Speciality Museums
# Art in Island                                                                   Art Museums
# Fort Santiago                                                        Historic Sites • Parks
# Bonifacio Global City                                        Points of Interest & Landmarks
# Intramuros                                           Neighborhoods • Historic Walking Areas
# Mall of Asia Arena                                       Arenas & Stadiums • Shopping Malls
# Robinsons Place Mall                                                         Shopping Malls
# Runway Manila                                                                       Bridges
# San Agustin Church                                                          Religious Sites
# San Agustin Museum                                                          History Museums
# The Mall of Asia Bay Area Amusement Park                            Amusement & Theme Parks
# Star City                                                           Amusement & Theme Parks
# SM Megamall                                                                  Shopping Malls
# Eastwood City                                                                 Neighborhoods
# Seaside Dampa                                                               Farmers Markets
# Ayala Triangle Gardens                                                              Gardens
# Greenhills Shopping Center                                                   Shopping Malls
# Manila Cathedral                                                            Religious Sites
# National Museum of Natural History                                  Natural History Museums
# Rizal Park                                                                            Parks
# Alabang Town Center                                                          Shopping Malls
# Venice Grand Canal Mall                                                      Shopping Malls
# Casa Manila                               Historic Sites • Points of Interest & Landmark...
# Ayala Museum                                                             Speciality Museums
# Manila American Cemetery and Memorial                                            Cemeteries
# National Museum Of Anthropology                                             History Museums
# Salcedo Saturday Market                                               Flea & Street Markets
# La Mesa Eco Park                                                                      Parks
# Manila Bay                                                                  Bodies of Water
# Philippine Air Force Aerospace Museum                                      Military Museums
#
#                                          tourist_site_location  \
# tourist_site_name
# National Museum                                    Manila City
# Art in Island                                      Quezon City
# Fort Santiago                                      Manila City
# Bonifacio Global City                              Taguig City
# Intramuros                                         Manila City
# Mall of Asia Arena                                  Pasay City
# Robinsons Place Mall                               Manila City
# Runway Manila                                       Pasay City
# San Agustin Church                                 Manila City
# San Agustin Museum                                 Manila City
# The Mall of Asia Bay Area Amusement Park            Pasay City
# Star City                                           Pasay City
# SM Megamall                                   Mandaluyong City
# Eastwood City                                      Quezon City
# Seaside Dampa                                       Pasay City
# Ayala Triangle Gardens                             Makati City
# Greenhills Shopping Center                       San Juan City
# Manila Cathedral                                   Manila City
# National Museum of Natural History                 Manila City
# Rizal Park                                         Manila City
# Alabang Town Center                            Muntinlupa City
# Venice Grand Canal Mall                            Taguig City
# Casa Manila                                        Manila City
# Ayala Museum                                       Makati City
# Manila American Cemetery and Memorial              Taguig City
# National Museum Of Anthropology                    Manila City
# Salcedo Saturday Market                            Makati City
# La Mesa Eco Park                                   Quezon City
# Manila Bay                                         Manila City
# Philippine Air Force Aerospace Museum               Pasay City
#
#                                          tourist_site_other_info_overall_rating  \
# tourist_site_name
# National Museum                                                         4.0/5.0
# Art in Island                                                           4.5/5.0
# Fort Santiago                                                           4.0/5.0
# Bonifacio Global City                                                   4.5/5.0
# Intramuros                                                              4.0/5.0
# Mall of Asia Arena                                                      4.0/5.0
# Robinsons Place Mall                                                    4.0/5.0
# Runway Manila                                                           5.0/5.0
# San Agustin Church                                                      4.5/5.0
# San Agustin Museum                                                      4.5/5.0
# The Mall of Asia Bay Area Amusement Park                                4.0/5.0
# Star City                                                               3.5/5.0
# SM Megamall                                                             4.5/5.0
# Eastwood City                                                           4.0/5.0
# Seaside Dampa                                                           4.0/5.0
# Ayala Triangle Gardens                                                  4.0/5.0
# Greenhills Shopping Center                                              4.0/5.0
# Manila Cathedral                                                        4.0/5.0
# National Museum of Natural History                                      4.5/5.0
# Rizal Park                                                              4.0/5.0
# Alabang Town Center                                                     4.5/5.0
# Venice Grand Canal Mall                                                 4.0/5.0
# Casa Manila                                                             4.0/5.0
# Ayala Museum                                                            4.5/5.0
# Manila American Cemetery and Memorial                                   4.5/5.0
# National Museum Of Anthropology                                         4.5/5.0
# Salcedo Saturday Market                                                 4.5/5.0
# La Mesa Eco Park                                                        4.0/5.0
# Manila Bay                                                              3.5/5.0
# Philippine Air Force Aerospace Museum                                   4.0/5.0
#
#                                                                        tourist_site_reviews  \
# tourist_site_name
# National Museum                           Review #1\nWe really loved the paintings at th...
# Art in Island                             Review #1\nit's a one-of-a-kind  showcase of a...
# Fort Santiago                             Review #1\nFort Santiago, as many already know...
# Bonifacio Global City                     Review #1\nNothing to to with Pilipino spirit,...
# Intramuros                                Review #1\nVery good & cooperative staff, if a...
# Mall of Asia Arena                        Review #1\nThis is by far the best arena for g...
# Robinsons Place Mall                      Review #1\nWe went to here during a vacation a...
# Runway Manila                             Review #1\nIts our first time to step at Runwa...
# San Agustin Church                        Review #1\nThis church is very historical. Thi...
# San Agustin Museum                        Review #1\nif you are a catholic this place is...
# The Mall of Asia Bay Area Amusement Park  Review #1\nI really liked the MOA EYE Ferris W...
# Star City                                 Review #1\nWe took our 7 year old daughter the...
# SM Megamall                               Review #1\nGreat mall to shop and get heaps of...
# Eastwood City                             Review #1\nThe view is good looking and there ...
# Seaside Dampa                             Review #1\nOMG what absolutely great value for...
# Ayala Triangle Gardens                    Review #1\nI was on my way to Lepanto Bldg jus...
# Greenhills Shopping Center                Review #1\nOritigas Geenhills Shopping will no...
# Manila Cathedral                          Review #1\nThe church is nice, but the plastic...
# National Museum of Natural History        Review #1\nThe National Museum of Natural Hist...
# Rizal Park                                Review #1\nThe park is really nice and it can ...
# Alabang Town Center                       Review #1\nAlabang Town Center has a very clea...
# Venice Grand Canal Mall                   Review #1\nI had a fun experience and loved sh...
# Casa Manila                               Review #1\nThis place is just so educational! ...
# Ayala Museum                              Review #1\nIt was my second time visiting the ...
# Manila American Cemetery and Memorial     Review #1\nwith arguably the best american bat...
# National Museum Of Anthropology           Review #1\nI've been to the National Museum of...
# Salcedo Saturday Market                   Review #1\nAmazing market with everything from...
# La Mesa Eco Park                          Review #1\nVisited way back approximately 10 y...
# Manila Bay                                Review #1\nSince Manila elected a young, dynam...
# Philippine Air Force Aerospace Museum     Review #1\nThe Aerospace museum presents the h...
#
#                                           approx_visitors_per_year_in_thousands  \
# tourist_site_name
# National Museum                                                             730
# Art in Island                                                                50
# Fort Santiago                                                             37000
# Bonifacio Global City                                                         0
# Intramuros                                                                37000
# Mall of Asia Arena                                                       189800
# Robinsons Place Mall                                                          0
# Runway Manila                                                                 0
# San Agustin Church                                                           10
# San Agustin Museum                                                            0
# The Mall of Asia Bay Area Amusement Park                                      0
# Star City                                                                     0
# SM Megamall                                                                   0
# Eastwood City                                                                 0
# Seaside Dampa                                                                18
# Ayala Triangle Gardens                                                        0
# Greenhills Shopping Center                                                    0
# Manila Cathedral                                                              0
# National Museum of Natural History                                         1197
# Rizal Park                                                                    0
# Alabang Town Center                                                           0
# Venice Grand Canal Mall                                                       0
# Casa Manila                                                                2120
# Ayala Museum                                                                 65
# Manila American Cemetery and Memorial                                         0
# National Museum Of Anthropology                                               0
# Salcedo Saturday Market                                                       0
# La Mesa Eco Park                                                              0
# Manila Bay                                                                    0
# Philippine Air Force Aerospace Museum                                         0
#
#                                           tourist_site_entance_fee_in_pesos
# tourist_site_name
# National Museum                                                           0
# Art in Island                                                           500
# Fort Santiago                                                             0
# Bonifacio Global City                                                     0
# Intramuros                                                               75
# Mall of Asia Arena                                                       50
# Robinsons Place Mall                                                      0
# Runway Manila                                                             0
# San Agustin Church                                                        0
# San Agustin Museum                                                      200
# The Mall of Asia Bay Area Amusement Park                                  0
# Star City                                                               490
# SM Megamall                                                               0
# Eastwood City                                                             0
# Seaside Dampa                                                             0
# Ayala Triangle Gardens                                                    0
# Greenhills Shopping Center                                                0
# Manila Cathedral                                                          0
# National Museum of Natural History                                        0
# Rizal Park                                                                0
# Alabang Town Center                                                       0
# Venice Grand Canal Mall                                                   0
# Casa Manila                                                              75
# Ayala Museum                                                            425
# Manila American Cemetery and Memorial                                     0
# National Museum Of Anthropology                                           0
# Salcedo Saturday Market                                                   0
# La Mesa Eco Park                                                         40
# Manila Bay                                                                0
# Philippine Air Force Aerospace Museum                                    20

# %%
final_df.to_csv('Tourist_site.csv', index = True)
