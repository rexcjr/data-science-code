# %% [markdown]
# # Prepare Restaurant data

# %%
# import needed libraries
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# # Web scraping www.zomato.com to extract restaurant data.
# <b>Disclaimers: </b>
#
# - All of the data extracted are not my own and are properties of www.zomato.com
# - Scraped data are not used for commercial purposes and purely for personal education purposes
# - HTML, format, tags, parameters, and other website script used as reference are working as of this writing and may change anytime by the website owner/administrators which may impact this code
# - The code blocks may take 0-2mins depending on hardware/software/network capabilities. If you want to rerun, patience is appreciated
# - Imported time module to avoid overloading the site and get blocked

# %% [markdown]
# ## Use Search Url and create BeautifulSoup object

# %%
headers = {
        'Access-Control-Allow-Origin': '*',
        'Access-Control-Allow-Methods': 'GET',
        'Access-Control-Allow-Headers': 'Content-Type',
        'Access-Control-Max-Age': '3600',
        "User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36"
    }

# get html text and create BeautifulSoup object 
search_url = 'https://www.zomato.com/manila/reopened-for-dine-in'
search_html = requests.get(search_url, headers = headers)    
search_soup = BeautifulSoup(search_html.text, 'html.parser')

# %% [markdown]
# ## Find the Restaurant links from the website search page and append to a list

# %%
# Use 3 comment lines below this to find the resto_link_class 
#resto_links = search_soup.find_all('a') 
#for link in resto_links[:200] :
    #print(link)
    
resto_link_class = {'class' : 'sc-cpUXGm sc-cXIWzj jQZAUH'} #this changes everytime you access 1st link(search_url)  
resto_links = search_soup.find_all('a', resto_link_class) 

#filter direct restaurant links and append to list
resto_links_lst = []
for link in resto_links : 
    if link.get('href').split('/')[4].strip() == 'restaurants' :
        continue
    else: resto_link = link.get('href').split('?')[0].strip()
    resto_links_lst.append(resto_link)

print('Scraping Complete!')
print('Count of Hotel Links : ', len(resto_links_lst) )
print('Sample Links:')
for link in resto_links_lst[0:3] : print(link)
# Out:
# Scraping Complete!
# Count of Hotel Links :  27
# Sample Links:
# https://www.zomato.com/manila/leanns-tea-house-tomas-morato-quezon-city
# https://www.zomato.com/manila/royal-indian-curry-house-poblacion-makati-city
# https://www.zomato.com/manila/sensei-bf-homes-parañaque-city

# %% [markdown]
# ## For each link in the list, scrape restaurant data

# %%
resto_main_dict = {}
for resto_link in resto_links_lst :
    resto_details_dict = {}
    resto_html = requests.get(resto_link, headers = headers)    
    resto_soup = BeautifulSoup(resto_html.text, 'lxml')
    
    #scrape restaurant name and add to dictionary
    resto_name = resto_soup.find('h1').get_text().split('/')[0]
    resto_details_dict['restaurant_name'] = resto_name
    
    #scrape restaurant location and add to dictionary
    loc_tag = resto_soup.find('p', {'class' : 'sc-1hez2tp-0 clKRrC'} )
    resto_loc = loc_tag.get_text().strip()
    resto_details_dict['restaurant_location'] = resto_loc
    
    #scrape restaurant specialty and add to dictionary
    resto_specialty = resto_soup.find('a', {'class' : 'sc-ibxdXY cgmKgO'}).get_text()
    resto_details_dict['resto_specialty'] = resto_specialty
    
    #scrape restaurant price range, seats and other info(restaurant is known for)
    info_tag = resto_soup.find_all('p', {'color' : '#4F4F4F'}, limit = 4)
   
    for info in info_tag :
        if info.get_text().count('PHP') >= 1 :
            resto_price = info.get_text()
            break
        else: 
            resto_other_info = info.get_text()
    seat_capacity = '''Seating Capacity varies from 10-50%, 
    depending on Alert Level''' # no exact no. of seats available in all review and resataurant social media sites
    
    resto_details_dict['restaurant_price_range'] = resto_price
    resto_details_dict['seat_capacity'] = seat_capacity
    resto_details_dict['restaurant_other_info'] = resto_other_info
    time.sleep(1)
    
    #create soup object for different url to scrape review and add to dictionary    
    review_html = requests.get(resto_link + '/reviews', headers = headers)    
    review_soup = BeautifulSoup(review_html.text, 'lxml')
    
    # Use 3 comment lines below this to find the resto_link_class 
    #review_tags = resto_soup.find_all('p')
    #for tag in review_tags :
        #print(tag)
       
    review_class = {'class' : 'sc-1hez2tp-0' }
    review_tags = review_soup.find_all('p', review_class)

    for tag in review_tags [-2:-1] : # this is the location of review text
        if len(tag.get_text()) == 0 :
            resto_review = 'no review text'
        else : 
            resto_review = (tag.get_text())
    resto_details_dict['restaurant_reviews'] = resto_review
    resto_main_dict[resto_name] = resto_details_dict
    # remaining reviews to be extracted 
    
    time.sleep(1)

print('Scraping Complete!')
# Out:
# Scraping Complete!

# %% [markdown]
# ## Dictionary to Pandas dataframe and clean data before saving to csv

# %%
df = pd.DataFrame.from_dict(resto_main_dict, orient = 'index')
print('Count of Rows: ', len(df))
df.head()
# Out:
# Count of Rows:  27
#                                    restaurant_name  \
# Leann's Tea House                Leann's Tea House
# Royal Indian Curry House  Royal Indian Curry House
# Sensei                                      Sensei
# La Cabrera                              La Cabrera
# Earth Kitchen                        Earth Kitchen
#
#                                                         restaurant_location  \
# Leann's Tea House         105-R Mother Ignacia Corner Sct. Madrinan Stre...
# Royal Indian Curry House   5345 General Luna Street, Poblacion, Makati City
# Sensei                         181 Aguirre Avenue, BF Homes, Parañaque City
# La Cabrera                Ayala Business Center, 6750 Ayala Avenue, Glor...
# Earth Kitchen             Lot 10 B-10 Katipunan Avenue, White Plains, Qu...
#
#                          resto_specialty  \
# Leann's Tea House                 Korean
# Royal Indian Curry House          Indian
# Sensei                          Japanese
# La Cabrera                     Argentine
# Earth Kitchen                    Italian
#
#                                                     restaurant_price_range  \
# Leann's Tea House          PHP700 for two people (approx.) Without alcohol
# Royal Indian Curry House  PHP2000 for two people (approx.) Without alcohol
# Sensei                     PHP800 for two people (approx.) Without alcohol
# La Cabrera                PHP2300 for two people (approx.) Without alcohol
# Earth Kitchen             PHP1200 for two people (approx.) Without alcohol
#
#                                                               seat_capacity  \
# Leann's Tea House         Seating Capacity varies from 10-50%, \n    dep...
# Royal Indian Curry House  Seating Capacity varies from 10-50%, \n    dep...
# Sensei                    Seating Capacity varies from 10-50%, \n    dep...
# La Cabrera                Seating Capacity varies from 10-50%, \n    dep...
# Earth Kitchen             Seating Capacity varies from 10-50%, \n    dep...
#
#                                                       restaurant_other_info  \
# Leann's Tea House         Courteous Staff, Friendly Staffs, Ample Seatin...
# Royal Indian Curry House  Awesome Food, Authenticity, Themed Decor, Gast...
# Sensei                    Fresh, Gastronomical Experience, Relaxed Atmos...
# La Cabrera                Comfortable Seating Area, Great Service, Manag...
# Earth Kitchen             Healthy Food, Good Food, Servings, Ambience, E...
#
#                                                          restaurant_reviews
# Leann's Tea House         This is probably one of the best K-bbq places ...
# Royal Indian Curry House           Best in the Philippines 5 star for RICH
# Sensei                                                       no review text
# La Cabrera                Di available ang 15 day aged rib eye that day ...
# Earth Kitchen             Pili nut was an unexpected but perfect pair wi...

# %%
df['restaurant_location'] = df['restaurant_location'].apply(lambda x: x.split(',')[-1].strip())
df.restaurant_location.loc[df['restaurant_location'] == 'Quezon City 1100'] = 'Quezon City'
df.restaurant_location.loc[df['restaurant_location'] == 'Quezon City 1101'] = 'Quezon City'
df
# Out:
#                                                                                       restaurant_name  \
# Leann's Tea House                                                                   Leann's Tea House
# Royal Indian Curry House                                                     Royal Indian Curry House
# Sensei                                                                                         Sensei
# La Cabrera                                                                                 La Cabrera
# Earth Kitchen                                                                           Earth Kitchen
# Silantro Fil-Mex                                                                     Silantro Fil-Mex
# Teppanya                                                                                     Teppanya
# Samba - Shangri-La at the Fort                                         Samba - Shangri-La at the Fort
# Antonio's                                                                                   Antonio's
# Ombu Kusina                                                                               Ombu Kusina
# Gino's Brick Oven Pizza                                                       Gino's Brick Oven Pizza
# Raging Bull Chophouse & Bar - Shangri-La at the...  Raging Bull Chophouse & Bar - Shangri-La at th...
# Planet Grapes                                                                           Planet Grapes
# Neil's Kitchen                                                                         Neil's Kitchen
# The Fat Seed Cafe + Roastery                                             The Fat Seed Cafe + Roastery
# Ninyo Fusion Cuisine & Wine Lounge                                 Ninyo Fusion Cuisine & Wine Lounge
# Tittos Latin BBQ & Brew                                                       Tittos Latin BBQ & Brew
# CoCo Ichibanya                                                                         CoCo Ichibanya
# Ramen Yushoken                                                                         Ramen Yushoken
# Van Gogh Is Bipolar                                                               Van Gogh Is Bipolar
# Ramen Nagi                                                                                 Ramen Nagi
# Mama Lou's Italian Kitchen                                                 Mama Lou's Italian Kitchen
# Your Local                                                                                 Your Local
# Buen Comer                                                                                 Buen Comer
# Saboten                                                                                       Saboten
# Brasserie Sagana                                                                     Brasserie Sagana
# Paradise Dynasty                                                                     Paradise Dynasty
#
#                                                    restaurant_location  \
# Leann's Tea House                                          Quezon City
# Royal Indian Curry House                                   Makati City
# Sensei                                                  Parañaque City
# La Cabrera                                                 Makati City
# Earth Kitchen                                              Quezon City
# Silantro Fil-Mex                                           Quezon City
# Teppanya                                                Las Piñas City
# Samba - Shangri-La at the Fort                             Taguig City
# Antonio's                                                Tagaytay City
# Ombu Kusina                                                Quezon City
# Gino's Brick Oven Pizza                                    Taguig City
# Raging Bull Chophouse & Bar - Shangri-La at the...         Taguig City
# Planet Grapes                                              Taguig City
# Neil's Kitchen                                         Muntinlupa City
# The Fat Seed Cafe + Roastery                               Quezon City
# Ninyo Fusion Cuisine & Wine Lounge                         Quezon City
# Tittos Latin BBQ & Brew                                     Pasig City
# CoCo Ichibanya                                           San Juan City
# Ramen Yushoken                                         Muntinlupa City
# Van Gogh Is Bipolar                                        Quezon City
# Ramen Nagi                                                 Quezon City
# Mama Lou's Italian Kitchen                                 Quezon City
# Your Local                                                 Makati City
# Buen Comer                                                 Quezon City
# Saboten                                                    Taguig City
# Brasserie Sagana                                           Taguig City
# Paradise Dynasty                                            Pasay City
#
#                                                    resto_specialty  \
# Leann's Tea House                                           Korean
# Royal Indian Curry House                                    Indian
# Sensei                                                    Japanese
# La Cabrera                                               Argentine
# Earth Kitchen                                              Italian
# Silantro Fil-Mex                                          Filipino
# Teppanya                                                  Japanese
# Samba - Shangri-La at the Fort                      Latin American
# Antonio's                                                   French
# Ombu Kusina                                               Filipino
# Gino's Brick Oven Pizza                                      Pizza
# Raging Bull Chophouse & Bar - Shangri-La at the...           Steak
# Planet Grapes                                             Filipino
# Neil's Kitchen                                            Filipino
# The Fat Seed Cafe + Roastery                              American
# Ninyo Fusion Cuisine & Wine Lounge                           Asian
# Tittos Latin BBQ & Brew                             Latin American
# CoCo Ichibanya                                            Japanese
# Ramen Yushoken                                            Japanese
# Van Gogh Is Bipolar                                       American
# Ramen Nagi                                                Japanese
# Mama Lou's Italian Kitchen                                 Italian
# Your Local                                                   Asian
# Buen Comer                                                 Tex-Mex
# Saboten                                                   Japanese
# Brasserie Sagana                                            French
# Paradise Dynasty                                           Chinese
#
#                                                                               restaurant_price_range  \
# Leann's Tea House                                    PHP700 for two people (approx.) Without alcohol
# Royal Indian Curry House                            PHP2000 for two people (approx.) Without alcohol
# Sensei                                               PHP800 for two people (approx.) Without alcohol
# La Cabrera                                          PHP2300 for two people (approx.) Without alcohol
# Earth Kitchen                                       PHP1200 for two people (approx.) Without alcohol
# Silantro Fil-Mex                                     PHP800 for two people (approx.) Without alcohol
# Teppanya                                            PHP1200 for two people (approx.) Without alcohol
# Samba - Shangri-La at the Fort                      PHP2500 for two people (approx.) Without alcohol
# Antonio's                                           PHP4500 for two people (approx.) Without alcohol
# Ombu Kusina                                          PHP800 for two people (approx.) Without alcohol
# Gino's Brick Oven Pizza                              PHP800 for two people (approx.) Without alcohol
# Raging Bull Chophouse & Bar - Shangri-La at the...  PHP2500 for two people (approx.) Without alcohol
# Planet Grapes                                       PHP1400 for two people (approx.) Without alcohol
# Neil's Kitchen                                      PHP1400 for two people (approx.) Without alcohol
# The Fat Seed Cafe + Roastery                        PHP1000 for two people (approx.) Without alcohol
# Ninyo Fusion Cuisine & Wine Lounge                  PHP3500 for two people (approx.) Without alcohol
# Tittos Latin BBQ & Brew                             PHP1200 for two people (approx.) Without alcohol
# CoCo Ichibanya                                      PHP1000 for two people (approx.) Without alcohol
# Ramen Yushoken                                      PHP1200 for two people (approx.) Without alcohol
# Van Gogh Is Bipolar                                 PHP2000 for two people (approx.) Without alcohol
# Ramen Nagi                                          PHP1200 for two people (approx.) Without alcohol
# Mama Lou's Italian Kitchen                          PHP1100 for two people (approx.) Without alcohol
